# %% [markdown]
# <a href="https://colab.research.google.com/github/Pittawas6330210206/bsc_dpdm22/blob/main/%E0%B8%A7%E0%B8%B4%E0%B9%80%E0%B8%84%E0%B8%A3%E0%B8%B2%E0%B8%B0%E0%B8%AB%E0%B9%8C%E0%B8%A5%E0%B8%B9%E0%B8%81%E0%B8%84%E0%B9%89%E0%B8%B2%E0%B8%A3%E0%B8%B1%E0%B8%9A%E0%B8%A3%E0%B8%96%E0%B9%83%E0%B8%AB%E0%B8%A1%E0%B9%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/โตโยต้าแก่นนคร')

# !pwd
# Out:
# /content/drive/MyDrive/โตโยต้าแก่นนคร

# %%
df = pd.read_excel('/content/drive/MyDrive/โตโยต้าแก่นนคร/แบบสำรวจการตลาดสำหรับลูกค้าออกรถใหม่ 2565 (การตอบกลับ) (1).xlsx')
print(df.shape)
df
# Out:
# (409, 18)
#       เพศ         อายุ                           อาชีพ  \
# 0    หญิง     31-40 ปี  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 1    หญิง     31-40 ปี        ข้าราชการหรือรัฐวิสาหกิจ
# 2    หญิง     41-50 ปี        ข้าราชการหรือรัฐวิสาหกิจ
# 3     ชาย  51 ปีขึ้นไป        ข้าราชการหรือรัฐวิสาหกิจ
# 4    หญิง     31-40 ปี          เกษตรหรือรับจ้างทั่วไป
# ..    ...          ...                             ...
# 404   ชาย     31-40 ปี          เกษตรหรือรับจ้างทั่วไป
# 405  หญิง     21-30 ปี              พนักงานบริษัทเอกชน
# 406   ชาย     21-30 ปี               นิสิตหรือนักศึกษา
# 407   ชาย     21-30 ปี              พนักงานบริษัทเอกชน
# 408  หญิง     31-40 ปี        ข้าราชการหรือรัฐวิสาหกิจ
#
#       การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด  \
# 0    เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# 1    เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# 2    เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# 3    เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# ...

# %% [markdown]
# ###Data Cleaning

# %%
df.columns
# Out:
# Index(['เพศ', 'อายุ', 'อาชีพ',
#        'การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด',
#        'ช่องทางการสื่อสารหรือการติดต่อสอบถามทางใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด  ',
#        'พนักงานขายประเภทใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด',
#        'การส่งเสริมการขายใดแบบมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด',
#        'กิจกรรมการตลาดใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด',
#        'หากท่านมีโอกาสเลือกซื้อรถยนต์คันต่อไป ท่านจะเลือกซื้อรถยนต์ที่โตโยต้าแก่นนครหรือไม่',
#        'ท่านทำรายการใดที่โชว์รูมโตโยต้าแก่นนคร', 'ข้อเสนอแนะ',
#        'ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]',
#        'ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]',
#        'ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]',
# ...

# %%
df.dtypes
# Out:
# เพศ                                                                                                                                                  object
# อายุ                                                                                                                                                 object
# อาชีพ                                                                                                                                                object
# การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                                                     object
# ช่องทางการสื่อสารหรือการติดต่อสอบถามทางใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                      object
# พนักงานขายประเภทใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                                             object
# ...

# %%
df.isnull().any()
# Out:
# เพศ                                                                                                                                                  False
# อายุ                                                                                                                                                 False
# อาชีพ                                                                                                                                                False
# การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                                                     False
# ช่องทางการสื่อสารหรือการติดต่อสอบถามทางใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                      False
# พนักงานขายประเภทใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                                             False
# ...

# %%
df['ท่านทำรายการใดที่โชว์รูมโตโยต้าแก่นนคร'] = df['ท่านทำรายการใดที่โชว์รูมโตโยต้าแก่นนคร'].fillna('ลูกค้ามารับรถใหม่')
df
# Out:
#       เพศ         อายุ                           อาชีพ  \
# 0    หญิง     31-40 ปี  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 1    หญิง     31-40 ปี        ข้าราชการหรือรัฐวิสาหกิจ
# 2    หญิง     41-50 ปี        ข้าราชการหรือรัฐวิสาหกิจ
# 3     ชาย  51 ปีขึ้นไป        ข้าราชการหรือรัฐวิสาหกิจ
# 4    หญิง     31-40 ปี          เกษตรหรือรับจ้างทั่วไป
# ..    ...          ...                             ...
# 404   ชาย     31-40 ปี          เกษตรหรือรับจ้างทั่วไป
# 405  หญิง     21-30 ปี              พนักงานบริษัทเอกชน
# 406   ชาย     21-30 ปี               นิสิตหรือนักศึกษา
# 407   ชาย     21-30 ปี              พนักงานบริษัทเอกชน
# 408  หญิง     31-40 ปี        ข้าราชการหรือรัฐวิสาหกิจ
#
#       การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด  \
# 0    เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# 1    เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# 2    เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# 3    เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# ...

# %%
df = df.dropna(subset=['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]','ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]','ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]','ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]','ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]','ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]',])
df
# Out:
#       เพศ         อายุ                           อาชีพ  \
# 36   หญิง  51 ปีขึ้นไป  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 37   หญิง  51 ปีขึ้นไป  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 38   หญิง     31-40 ปี  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 39   หญิง     41-50 ปี        ข้าราชการหรือรัฐวิสาหกิจ
# 40   หญิง     31-40 ปี  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# ..    ...          ...                             ...
# 404   ชาย     31-40 ปี          เกษตรหรือรับจ้างทั่วไป
# 405  หญิง     21-30 ปี              พนักงานบริษัทเอกชน
# 406   ชาย     21-30 ปี               นิสิตหรือนักศึกษา
# 407   ชาย     21-30 ปี              พนักงานบริษัทเอกชน
# 408  หญิง     31-40 ปี        ข้าราชการหรือรัฐวิสาหกิจ
#
#       การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด  \
# 36                           ป้ายโฆษณาตามสถานที่ต่าง ๆ
# 37   เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# 38                                         เพื่อนแนะนำ
# 39                                       งานแสดงรถยนต์
# ...

# %% [markdown]
# ### จัดการคะแนนความพึงพอใจ

# %%
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("เห็นด้วยอย่างมาก (5)", 5)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("เห็นด้วย(4)", 4)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("เฉยๆ(3)", 3)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("ไม่เห็นด้วย (2)", 2)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("ไม่เห็นด้วยอย่างมาก(1)", 1)
# Out:
# <ipython-input-10-d085f171e7a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("เห็นด้วยอย่างมาก (5)", 5)
# <ipython-input-10-d085f171e7a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'].replace("เห็นด้วยอย่างมาก (5)", 5)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'].replace("เห็นด้วย(4)", 4)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'].replace("เฉยๆ(3)", 3)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'].replace("ไม่เห็นด้วย (2)", 2)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'].replace("ไม่เห็นด้วยอย่างมาก(1)",1)
# Out:
# <ipython-input-11-0716e5d210cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'].replace("เห็นด้วยอย่างมาก (5)", 5)
# <ipython-input-11-0716e5d210cc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'].replace("เห็นด้วยอย่างมาก (5)", 5)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'].replace("เห็นด้วย(4)", 4)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'].replace("เฉยๆ(3)", 3)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'].replace("ไม่เห็นด้วย (2)", 2)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'].replace("ไม่เห็นด้วยอย่างมาก(1)", 1)
# Out:
# <ipython-input-12-0794131bf6b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'].replace("เห็นด้วยอย่างมาก (5)", 5)
# <ipython-input-12-0794131bf6b2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'].replace("เห็นด้วยอย่างมาก (5)", 5)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'].replace("เห็นด้วย(4)", 4)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'].replace("เฉยๆ(3)", 3)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'].replace("ไม่เห็นด้วย (2)", 2)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'].replace("ไม่เห็นด้วยอย่างมาก(1)", 1)
# Out:
# <ipython-input-13-c5431f3bd901>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'].replace("เห็นด้วยอย่างมาก (5)", 5)
# <ipython-input-13-c5431f3bd901>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'].replace("เห็นด้วยอย่างมาก (5)", 5)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'].replace("เห็นด้วย(4)", 4)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'].replace("เฉยๆ(3)", 3)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'].replace("ไม่เห็นด้วย (2)", 2)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'].replace("ไม่เห็นด้วยอย่างมาก(1)", 1)
# Out:
# <ipython-input-14-48ba5de94094>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'].replace("เห็นด้วยอย่างมาก (5)", 5)
# <ipython-input-14-48ba5de94094>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("เห็นด้วยอย่างมาก (5)", 5)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("เห็นด้วย(4)", 4)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("เฉยๆ(3)", 3)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("ไม่เห็นด้วย (2)", 2)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("ไม่เห็นด้วยอย่างมาก(1)", 1)
# Out:
# <ipython-input-15-e61b5943ad06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].replace("เห็นด้วยอย่างมาก (5)", 5)
# <ipython-input-15-e61b5943ad06>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#       เพศ         อายุ                           อาชีพ  \
# 36   หญิง  51 ปีขึ้นไป  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 37   หญิง  51 ปีขึ้นไป  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 38   หญิง     31-40 ปี  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 39   หญิง     41-50 ปี        ข้าราชการหรือรัฐวิสาหกิจ
# 40   หญิง     31-40 ปี  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# ..    ...          ...                             ...
# 404   ชาย     31-40 ปี          เกษตรหรือรับจ้างทั่วไป
# 405  หญิง     21-30 ปี              พนักงานบริษัทเอกชน
# 406   ชาย     21-30 ปี               นิสิตหรือนักศึกษา
# 407   ชาย     21-30 ปี              พนักงานบริษัทเอกชน
# 408  หญิง     31-40 ปี        ข้าราชการหรือรัฐวิสาหกิจ
#
#       การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด  \
# 36                           ป้ายโฆษณาตามสถานที่ต่าง ๆ
# 37   เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# 38                                         เพื่อนแนะนำ
# 39                                       งานแสดงรถยนต์
# ...

# %%
df.isnull().any()
# Out:
# เพศ                                                                                                                                                  False
# อายุ                                                                                                                                                 False
# อาชีพ                                                                                                                                                False
# การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                                                     False
# ช่องทางการสื่อสารหรือการติดต่อสอบถามทางใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                      False
# พนักงานขายประเภทใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                                             False
# ...

# %%
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].astype(int)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [การรับชม/ดูสื่อประชาสัมพันธ์ทำให้มีผลต่อการตัดสินใจซื้อรถยนต์]'].astype(int)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักให้ความสนใจในรายละเอียดหรือรุ่นรถยนต์ที่ได้รับชม/ดูจากสื่อประชาสัมพันธ์]'].astype(int)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [รูปแบบการนำเสนอสื่อประชาสัมพันธ์มีผลต่อความเข้าใจในตัวรถยนต์ของท่าน]'].astype(int)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [เมื่อท่านได้รับชม/ดูสื่อประชาสัมพันธ์ทำให้สามารถเข้าใจและจดจำคุณสมบติของรถยนต์มากขึ้น]'].astype(int)
df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านมักจำสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].astype(int)
# Out:
# <ipython-input-18-23c48b509598>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'] = df['ระดับการรับรู้สื่อประชาสัมพันธ์ของท่าน [ท่านจะรับชม/ดูสื่อประชาสัมพันธ์รถยนต์ที่มีพรีเซ็นเตอร์เป็นคนมีชื่อเสียง  เช่น  นักร้อง/นักแสดงที่ชื่นชอบ]'].astype(int)
# <ipython-input-18-23c48b509598>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.dtypes
# Out:
# เพศ                                                                                                                                                  object
# อายุ                                                                                                                                                 object
# อาชีพ                                                                                                                                                object
# การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                                                     object
# ช่องทางการสื่อสารหรือการติดต่อสอบถามทางใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                      object
# พนักงานขายประเภทใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด                                                                                             object
# ...

# %%
df
# Out:
#       เพศ         อายุ                           อาชีพ  \
# 36   หญิง  51 ปีขึ้นไป  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 37   หญิง  51 ปีขึ้นไป  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 38   หญิง     31-40 ปี  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# 39   หญิง     41-50 ปี        ข้าราชการหรือรัฐวิสาหกิจ
# 40   หญิง     31-40 ปี  ธุรกิจส่วนตัวหรือเจ้าของกิจการ
# ..    ...          ...                             ...
# 404   ชาย     31-40 ปี          เกษตรหรือรับจ้างทั่วไป
# 405  หญิง     21-30 ปี              พนักงานบริษัทเอกชน
# 406   ชาย     21-30 ปี               นิสิตหรือนักศึกษา
# 407   ชาย     21-30 ปี              พนักงานบริษัทเอกชน
# 408  หญิง     31-40 ปี        ข้าราชการหรือรัฐวิสาหกิจ
#
#       การโฆษณาใดมีผลต่อการตัดสินใจซื้อของท่านมากที่สุด  \
# 36                           ป้ายโฆษณาตามสถานที่ต่าง ๆ
# 37   เว็บไซต์/ สื่อออนไลน์ เช่น Facebook / Line / Y...
# 38                                         เพื่อนแนะนำ
# 39                                       งานแสดงรถยนต์
# ...

# %% [markdown]
# ## เซฟไฟล์ลง google dive

# %%
df.to_excel('df.xlsx', index=False)
