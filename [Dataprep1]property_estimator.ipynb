# %% [markdown]
# <a href="https://colab.research.google.com/github/Pittawas6330210206/bsc_dpdm22/blob/main/%5BDataprep1%5Dproperty_estimator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
Data = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx', index_col=0).reset_index()
Data
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
post1 = Data[Data['ID ผู้ประเมิน']==1]
post1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
post1.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %%
post1['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
post1['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %%
import matplotlib

# %%
from matplotlib import pyplot as plt

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
post1_score = plt.hist(post1['ให้คะแนนทรัพย์'])
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3], <a list of 4 Text major ticklabel objects>)

# %%
post2 = Data[Data['ID ผู้ประเมิน']==2]
post2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
post2.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count           90.0  9.000000e+01         8.900000e+01         0.0
# mean             2.0  4.240733e+06         4.153258e+06         NaN
# std              0.0  2.714815e+06         2.386901e+06         NaN
# min              2.0  3.900000e+05         9.900000e+05         NaN
# 25%              2.0  2.860000e+06         2.600000e+06         NaN
# 50%              2.0  4.000000e+06         3.900000e+06         NaN
# 75%              2.0  5.000000e+06         4.900000e+06         NaN
# max              2.0  2.094900e+07         1.700000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          0.0
# mean           NaN          NaN          NaN          NaN
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN          NaN
# 25%            NaN          NaN          NaN          NaN
# ...

# %%
post2['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %%
post2['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# ## HW1

# %% [markdown]
# ##เปรียบเทียบความต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขายใช้ MAPE เป็นเกณฑ์ในการเรียบเทียบ

# %% [markdown]
# ##บ้านเดี่ยว

# %%
#merge โดยใช้คี่ย์หลักเป็น post id	ใช้ map()

# %%
post1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %%
post2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# ...

# %% [markdown]
# #นักประเมินคนที่2 เป็นหลัก

# %%
post2['ประเมิน1'] = post2['post id'].map(post1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
post2
# Out:
# <ipython-input-94-d30718df4ee8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   post2['ประเมิน1'] = post2['post id'].map(post1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# ...

# %%
post2_1 = post2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
post2_1
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 185              2  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 186              2  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 187              2     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 188              2     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 189              2    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์   ประเมิน2  \
# ...

# %%
est2_1=post2_1[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
est2_1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [90 rows x 4 columns]

# %%
est2_1.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2       True
# dtype: bool

# %%
est2_1[['ประเมิน2']]  = est2_1[['ประเมิน2']].fillna(0)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
est2_1.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
est2_1
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [90 rows x 4 columns]

# %% [markdown]
# ## เขียนฟังก์ชั่นตรวจสอบค่าที่เติม 0 ผิด

# %%
A = est2_1['ราคาทรัพย์']
B = est2_1['ประเมิน1']
C = est2_1['ประเมิน2']

# %%
A/B
# Out:
# 1      1.080000
# 3      1.181818
# 5      1.180000
# 7      1.257143
# 9      1.100000
#          ...
# 185    1.222222
# 186    1.521346
# 187    0.555556
# 188    1.000000
# 189    1.145833
# Length: 90, dtype: float64

# %%
B/A
# Out:
# 1      0.925926
# 3      0.846154
# 5      0.847458
# 7      0.795455
# 9      0.909091
#          ...
# 185    0.818182
# 186    0.657313
# 187    1.800000
# 188    1.000000
# 189    0.872727
# Length: 90, dtype: float64

# %%
def my_function(ราคาทรัพย์, ประเมิน1):
    return max(A/B,B/A)

# %%
max(B/C)
# Out:
# inf

# %%
max(C/B)
# Out:
# 2.1666666666666665

# %%
#my_function(A,B)

# %% [markdown]
# ## สร้างคลอลัมท์ใหม่ลงในตาราง home โดยค่าคลอลัมท์คือค่าทีจาก function check ราคาตั้งขายจากนักประเมิน1

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
x_true = est2_1['ราคาทรัพย์']
y_pred = est2_1['ประเมิน1']
z_pred = est2_1['ประเมิน2']

# %%
mean_absolute_percentage_error(x_true, y_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ{mean_absolute_percentage_error(x_true, y_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ0.12295717665618242

# %%
mean_absolute_percentage_error(x_true, z_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ{mean_absolute_percentage_error(x_true, z_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ0.11413046131476379

# %% [markdown]
# #นักประเมินคนที่1 เป็นหลัก

# %%
post1['ประเมิน2'] = post1['post id'].map(post2.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
post1
# Out:
# <ipython-input-105-25e08f70b756>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   post1['ประเมิน2'] = post1['post id'].map(post2.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# ...

# %%
post1_2 = post1.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน1"})
post1_2
# Out:
#      ID ผู้ประเมิน                                post id property_type  \
# 0                1     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2                1     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4                1    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6                1    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8                1    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# 155              1  https://nayoo.co/khonkaen/posts/19495    บ้านเดี่ยว
# 156              1  https://nayoo.co/khonkaen/posts/19496    บ้านเดี่ยว
# 157              1     https://nayoo.co/khonkaen/posts/20    บ้านเดี่ยว
# 158              1     https://nayoo.co/khonkaen/posts/31    บ้านเดี่ยว
# 159              1    https://nayoo.co/khonkaen/posts/570    บ้านเดี่ยว
#
#     ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์   ประเมิน1  \
# ...

# %%
est1_2=post1_2[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
est1_2
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 0       https://nayoo.co/khonkaen/posts/25   2700000.0  2500000.0  2700000.0
# 2       https://nayoo.co/khonkaen/posts/33   2600000.0  2200000.0  2400000.0
# 4      https://nayoo.co/khonkaen/posts/495   5900000.0  5000000.0  9000000.0
# 6      https://nayoo.co/khonkaen/posts/564   4400000.0  3500000.0  3700000.0
# 8      https://nayoo.co/khonkaen/posts/566   2750000.0  2500000.0  2500000.0
# ..                                     ...         ...        ...        ...
# 155  https://nayoo.co/khonkaen/posts/19495   5500000.0  4500000.0  5000000.0
# 156  https://nayoo.co/khonkaen/posts/19496   7911000.0  5200000.0  7400000.0
# 157     https://nayoo.co/khonkaen/posts/20   2000000.0  3600000.0  2500000.0
# 158     https://nayoo.co/khonkaen/posts/31   4000000.0  4000000.0  3900000.0
# 159    https://nayoo.co/khonkaen/posts/570   1375000.0  1200000.0  1400000.0
#
# [100 rows x 4 columns]

# %%
est1_2.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2       True
# dtype: bool

# %%
est1_2[['ประเมิน2']]  = est1_2[['ประเมิน2']].fillna(0)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
est1_2.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
x_true = est1_2['ราคาทรัพย์']
y_pred = est1_2['ประเมิน1']
z_pred = est1_2['ประเมิน2']

# %%
mean_absolute_percentage_error(x_true, y_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ{mean_absolute_percentage_error(x_true, y_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ0.12133451335450657

# %%
mean_absolute_percentage_error(x_true, z_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ{mean_absolute_percentage_error(x_true, z_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ0.20271741518328742

# %% [markdown]
# ##ที่ดิน

# %%
Data1 = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx',sheet_name=1).reset_index()
Data1
# Out:
#      index  ID ผู้ประเมิน                                post id  \
# 0        0              1   https://nayoo.co/khonkaen/posts/1033
# 1        1              2   https://nayoo.co/khonkaen/posts/1033
# 2        2              4   https://nayoo.co/khonkaen/posts/1033
# 3        3              1   https://nayoo.co/khonkaen/posts/1711
# 4        4              2   https://nayoo.co/khonkaen/posts/1711
# ..     ...            ...                                    ...
# 205    205              1  https://nayoo.co/khonkaen/posts/17093
# 206    206              2  https://nayoo.co/khonkaen/posts/17112
# 207    207              1  https://nayoo.co/khonkaen/posts/17112
# 208    208              2  https://nayoo.co/khonkaen/posts/17145
# 209    209              1  https://nayoo.co/khonkaen/posts/17145
#
#     property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 0          ที่ดิน                        มั่นใจ     2800000
# 1          ที่ดิน                        มั่นใจ     2800000
# ...

# %%
post_land1 = Data1[Data1['ID ผู้ประเมิน']==1]
post_land1
# Out:
#      index  ID ผู้ประเมิน                                post id  \
# 0        0              1   https://nayoo.co/khonkaen/posts/1033
# 3        3              1   https://nayoo.co/khonkaen/posts/1711
# 6        6              1   https://nayoo.co/khonkaen/posts/1726
# 9        9              1   https://nayoo.co/khonkaen/posts/1732
# 12      12              1   https://nayoo.co/khonkaen/posts/1866
# ..     ...            ...                                    ...
# 201    201              1  https://nayoo.co/khonkaen/posts/14539
# 203    203              1  https://nayoo.co/khonkaen/posts/16072
# 205    205              1  https://nayoo.co/khonkaen/posts/17093
# 207    207              1  https://nayoo.co/khonkaen/posts/17112
# 209    209              1  https://nayoo.co/khonkaen/posts/17145
#
#     property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 0          ที่ดิน                        มั่นใจ     2800000
# 3          ที่ดิน                        มั่นใจ    14900000
# ...

# %%
post_land2 = Data1[Data1['ID ผู้ประเมิน']==2]
post_land2
# Out:
#      index  ID ผู้ประเมิน                                post id  \
# 1        1              2   https://nayoo.co/khonkaen/posts/1033
# 4        4              2   https://nayoo.co/khonkaen/posts/1711
# 7        7              2   https://nayoo.co/khonkaen/posts/1726
# 10      10              2   https://nayoo.co/khonkaen/posts/1732
# 13      13              2   https://nayoo.co/khonkaen/posts/1866
# ..     ...            ...                                    ...
# 200    200              2  https://nayoo.co/khonkaen/posts/14539
# 202    202              2  https://nayoo.co/khonkaen/posts/16072
# 204    204              2  https://nayoo.co/khonkaen/posts/17093
# 206    206              2  https://nayoo.co/khonkaen/posts/17112
# 208    208              2  https://nayoo.co/khonkaen/posts/17145
#
#     property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 1          ที่ดิน                        มั่นใจ     2800000
# 4          ที่ดิน                        มั่นใจ    14900000
# ...

# %%
post_land2['ประเมิน1'] = post_land2['post id'].map(post_land1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
post_land2
# Out:
# <ipython-input-117-4a72d445f75d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   post_land2['ประเมิน1'] = post_land2['post id'].map(post_land1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      index  ID ผู้ประเมิน                                post id  \
# 1        1              2   https://nayoo.co/khonkaen/posts/1033
# 4        4              2   https://nayoo.co/khonkaen/posts/1711
# 7        7              2   https://nayoo.co/khonkaen/posts/1726
# 10      10              2   https://nayoo.co/khonkaen/posts/1732
# 13      13              2   https://nayoo.co/khonkaen/posts/1866
# ..     ...            ...                                    ...
# 200    200              2  https://nayoo.co/khonkaen/posts/14539
# ...

# %%
post_land2_1 = post_land2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
post_land2_1
# Out:
#      index  ID ผู้ประเมิน                                post id  \
# 1        1              2   https://nayoo.co/khonkaen/posts/1033
# 4        4              2   https://nayoo.co/khonkaen/posts/1711
# 7        7              2   https://nayoo.co/khonkaen/posts/1726
# 10      10              2   https://nayoo.co/khonkaen/posts/1732
# 13      13              2   https://nayoo.co/khonkaen/posts/1866
# ..     ...            ...                                    ...
# 200    200              2  https://nayoo.co/khonkaen/posts/14539
# 202    202              2  https://nayoo.co/khonkaen/posts/16072
# 204    204              2  https://nayoo.co/khonkaen/posts/17093
# 206    206              2  https://nayoo.co/khonkaen/posts/17112
# 208    208              2  https://nayoo.co/khonkaen/posts/17145
#
#     property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์    ประเมิน2  \
# 1          ที่ดิน                        มั่นใจ     2800000   2000000.0
# ...

# %%
total_land = post_land2_1[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
total_land
# Out:
#                                    post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/1033     2800000   1800000.0   2000000.0
# 4     https://nayoo.co/khonkaen/posts/1711    14900000   8000000.0  12000000.0
# 7     https://nayoo.co/khonkaen/posts/1726    90000000  18000000.0  70000000.0
# 10    https://nayoo.co/khonkaen/posts/1732    65000000  35000000.0  60000000.0
# 13    https://nayoo.co/khonkaen/posts/1866     3000000   2200000.0   2500000.0
# ..                                     ...         ...         ...         ...
# 200  https://nayoo.co/khonkaen/posts/14539     5000000   4000000.0   4000000.0
# 202  https://nayoo.co/khonkaen/posts/16072      750000    500000.0    750000.0
# 204  https://nayoo.co/khonkaen/posts/17093     2650000   2000000.0   2500000.0
# 206  https://nayoo.co/khonkaen/posts/17112     1300000   1500000.0   1500000.0
# 208  https://nayoo.co/khonkaen/posts/17145     3000000   2500000.0   2800000.0
#
# [100 rows x 4 columns]

# %%
total_land.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
x_true = total_land['ราคาทรัพย์']
y_pred = total_land['ประเมิน1']
z_pred = total_land['ประเมิน2']

# %%
mean_absolute_percentage_error(x_true, y_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ{mean_absolute_percentage_error(x_true, y_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ0.41337842594528956

# %%
mean_absolute_percentage_error(x_true, z_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ{mean_absolute_percentage_error(x_true, z_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ0.40118780382843416

# %% [markdown]
# ##คอนโด

# %%
Data2 = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx',sheet_name=2).reset_index()
Data2
# Out:
#    index  ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0      0              1     32.0         คอนโด                        มั่นใจ
# 1      1              1     36.0         คอนโด                        มั่นใจ
# 2      2              1    603.0         คอนโด                        มั่นใจ
# 3      3              1   1395.0         คอนโด                        มั่นใจ
# 4      4              1   1443.0         คอนโด                        มั่นใจ
# 5      5              1   1609.0         คอนโด                        มั่นใจ
# 6      6              1   1640.0         คอนโด                        มั่นใจ
# 7      7              1   1641.0         คอนโด                        มั่นใจ
# 8      8              1   1650.0         คอนโด                        มั่นใจ
# 9      9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# ...

# %%
post_condo1 = Data2[Data2['ID ผู้ประเมิน']==1]
post_condo1
# Out:
#    index  ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0      0              1     32.0         คอนโด                        มั่นใจ
# 1      1              1     36.0         คอนโด                        มั่นใจ
# 2      2              1    603.0         คอนโด                        มั่นใจ
# 3      3              1   1395.0         คอนโด                        มั่นใจ
# 4      4              1   1443.0         คอนโด                        มั่นใจ
# 5      5              1   1609.0         คอนโด                        มั่นใจ
# 6      6              1   1640.0         คอนโด                        มั่นใจ
# 7      7              1   1641.0         คอนโด                        มั่นใจ
# 8      8              1   1650.0         คอนโด                        มั่นใจ
# 9      9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# ...

# %%
post_condo2 = Data2[Data2['ID ผู้ประเมิน']==2]
post_condo2
# Out:
# Empty DataFrame
# Columns: [index, ID ผู้ประเมิน, post id, property_type, ความมั่นใจในการเมินราคาทรัพย์, ราคาทรัพย์, ประเมินราคาซื้อ-ขาย, ปัจจัยในการประเมินราคาซื้อ-ขาย, เหตุผลไม่มั่นใจราคาประเมิน, ให้คะแนนทรัพย์, Unnamed: 9, Unnamed: 10]
# Index: []

# %%
post_condo1_1 = post_condo1.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน1"})
post_condo1_1
# Out:
#    index  ID ผู้ประเมิน  post id property_type ความมั่นใจในการเมินราคาทรัพย์  \
# 0      0              1     32.0         คอนโด                        มั่นใจ
# 1      1              1     36.0         คอนโด                        มั่นใจ
# 2      2              1    603.0         คอนโด                        มั่นใจ
# 3      3              1   1395.0         คอนโด                        มั่นใจ
# 4      4              1   1443.0         คอนโด                        มั่นใจ
# 5      5              1   1609.0         คอนโด                        มั่นใจ
# 6      6              1   1640.0         คอนโด                        มั่นใจ
# 7      7              1   1641.0         คอนโด                        มั่นใจ
# 8      8              1   1650.0         คอนโด                        มั่นใจ
# 9      9              1   1840.0         คอนโด                        มั่นใจ
#
#    ราคาทรัพย์   ประเมิน1 ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0   3500000.0  3500000.0   60,000-130,000 บาท/ตารางเมตร
# ...

# %%
total_condo = post_condo1_1[['post id','ราคาทรัพย์','ประเมิน1']]
total_condo
# Out:
#    post id  ราคาทรัพย์   ประเมิน1
# 0     32.0   3500000.0  3500000.0
# 1     36.0   1930000.0  2200000.0
# 2    603.0   2438000.0  2800000.0
# 3   1395.0   1600000.0  2300000.0
# 4   1443.0   1860000.0  1800000.0
# 5   1609.0   1490000.0  1500000.0
# 6   1640.0   1280000.0  1600000.0
# 7   1641.0   4290000.0  2700000.0
# 8   1650.0   1700000.0  1550000.0
# 9   1840.0   3790000.0  2800000.0

# %%
x_true = total_condo['ราคาทรัพย์']
y_pred = total_condo['ประเมิน1']

# %%
mean_absolute_percentage_error(x_true, y_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ{mean_absolute_percentage_error(x_true, y_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ0.17349265946250259

# %% [markdown]
# ##ทาวน์โฮม

# %%
Data3 = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx',sheet_name=3).reset_index()
Data3
# Out:
#      index  ID ผู้ประเมิน                                post id  \
# 0        0              1    https://nayoo.co/khonkaen/posts/548
# 1        1              2    https://nayoo.co/khonkaen/posts/548
# 2        2              1    https://nayoo.co/khonkaen/posts/549
# 3        3              2    https://nayoo.co/khonkaen/posts/549
# 4        4              1    https://nayoo.co/khonkaen/posts/579
# ..     ...            ...                                    ...
# 235    235              2  https://nayoo.co/khonkaen/posts/18547
# 236    236              2  https://nayoo.co/khonkaen/posts/18551
# 237    237              2  https://nayoo.co/khonkaen/posts/19434
# 238    238              2  https://nayoo.co/khonkaen/posts/19501
# 239    239              2  https://nayoo.co/khonkaen/posts/20367
#
#     property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 0        ทาวน์โฮม                        มั่นใจ   1045000.0
# 1        ทาวน์โฮม                        มั่นใจ   1045000.0
# ...

# %%
post_townhome1 = Data3[Data3['ID ผู้ประเมิน']==1]
post_townhome1
# Out:
#      index  ID ผู้ประเมิน                                post id  \
# 0        0              1    https://nayoo.co/khonkaen/posts/548
# 2        2              1    https://nayoo.co/khonkaen/posts/549
# 4        4              1    https://nayoo.co/khonkaen/posts/579
# 6        6              1    https://nayoo.co/khonkaen/posts/580
# 8        8              1    https://nayoo.co/khonkaen/posts/582
# ..     ...            ...                                    ...
# 125    125              1  https://nayoo.co/khonkaen/posts/18547
# 126    126              1  https://nayoo.co/khonkaen/posts/18551
# 127    127              1  https://nayoo.co/khonkaen/posts/19434
# 128    128              1  https://nayoo.co/khonkaen/posts/19501
# 129    129              1  https://nayoo.co/khonkaen/posts/20367
#
#     property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 0        ทาวน์โฮม                        มั่นใจ   1045000.0
# 2        ทาวน์โฮม                        มั่นใจ    935000.0
# ...

# %%
post_townhome2 = Data3[Data3['ID ผู้ประเมิน']==2]
post_townhome2
# Out:
#      index  ID ผู้ประเมิน                                post id  \
# 1        1              2    https://nayoo.co/khonkaen/posts/548
# 3        3              2    https://nayoo.co/khonkaen/posts/549
# 5        5              2    https://nayoo.co/khonkaen/posts/579
# 7        7              2    https://nayoo.co/khonkaen/posts/580
# 9        9              2    https://nayoo.co/khonkaen/posts/582
# ..     ...            ...                                    ...
# 235    235              2  https://nayoo.co/khonkaen/posts/18547
# 236    236              2  https://nayoo.co/khonkaen/posts/18551
# 237    237              2  https://nayoo.co/khonkaen/posts/19434
# 238    238              2  https://nayoo.co/khonkaen/posts/19501
# 239    239              2  https://nayoo.co/khonkaen/posts/20367
#
#     property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 1        ทาวน์โฮม                        มั่นใจ   1045000.0
# 3        ทาวน์โฮม                        มั่นใจ    935000.0
# ...

# %%
post_townhome2['ประเมิน1'] = post_townhome2['post id'].map(post_townhome1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
post_townhome2
# Out:
# <ipython-input-134-858e3022158c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   post_townhome2['ประเมิน1'] = post_townhome2['post id'].map(post_townhome1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      index  ID ผู้ประเมิน                                post id  \
# 1        1              2    https://nayoo.co/khonkaen/posts/548
# 3        3              2    https://nayoo.co/khonkaen/posts/549
# 5        5              2    https://nayoo.co/khonkaen/posts/579
# 7        7              2    https://nayoo.co/khonkaen/posts/580
# 9        9              2    https://nayoo.co/khonkaen/posts/582
# ..     ...            ...                                    ...
# 235    235              2  https://nayoo.co/khonkaen/posts/18547
# ...

# %%
post_townhome2_1 = post_townhome2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
post_townhome2_1
# Out:
#      index  ID ผู้ประเมิน                                post id  \
# 1        1              2    https://nayoo.co/khonkaen/posts/548
# 3        3              2    https://nayoo.co/khonkaen/posts/549
# 5        5              2    https://nayoo.co/khonkaen/posts/579
# 7        7              2    https://nayoo.co/khonkaen/posts/580
# 9        9              2    https://nayoo.co/khonkaen/posts/582
# ..     ...            ...                                    ...
# 235    235              2  https://nayoo.co/khonkaen/posts/18547
# 236    236              2  https://nayoo.co/khonkaen/posts/18551
# 237    237              2  https://nayoo.co/khonkaen/posts/19434
# 238    238              2  https://nayoo.co/khonkaen/posts/19501
# 239    239              2  https://nayoo.co/khonkaen/posts/20367
#
#     property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์   ประเมิน2  \
# 1        ทาวน์โฮม                        มั่นใจ   1045000.0  1500000.0
# ...

# %%
total_townhome = post_townhome2_1[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
total_townhome
# Out:
#                                    post id  ราคาทรัพย์   ประเมิน1   ประเมิน2
# 1      https://nayoo.co/khonkaen/posts/548   1045000.0   700000.0  1500000.0
# 3      https://nayoo.co/khonkaen/posts/549    935000.0   700000.0  1500000.0
# 5      https://nayoo.co/khonkaen/posts/579   3520000.0  3500000.0  4000000.0
# 7      https://nayoo.co/khonkaen/posts/580   3850000.0  3500000.0  3200000.0
# 9      https://nayoo.co/khonkaen/posts/582    990000.0  1000000.0   800000.0
# ..                                     ...         ...        ...        ...
# 235  https://nayoo.co/khonkaen/posts/18547   1430000.0  1000000.0  1200000.0
# 236  https://nayoo.co/khonkaen/posts/18551   1980000.0  1500000.0  1700000.0
# 237  https://nayoo.co/khonkaen/posts/19434   2000000.0  1600000.0  1900000.0
# 238  https://nayoo.co/khonkaen/posts/19501   1790000.0  1600000.0  1700000.0
# 239  https://nayoo.co/khonkaen/posts/20367   1590000.0  1700000.0  1700000.0
#
# [120 rows x 4 columns]

# %%
total_townhome.isnull().any()
# Out:
# post id       False
# ราคาทรัพย์    False
# ประเมิน1      False
# ประเมิน2      False
# dtype: bool

# %%
x_true = total_townhome['ราคาทรัพย์']
y_pred = total_townhome['ประเมิน1']
z_pred = total_townhome['ประเมิน2']

# %%
mean_absolute_percentage_error(x_true, y_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ{mean_absolute_percentage_error(x_true, y_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ0.11373507980201533

# %%
mean_absolute_percentage_error(x_true, z_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ{mean_absolute_percentage_error(x_true, z_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ0.08766742521930593

# %% [markdown]
# ##อาคารพาณิชย์

# %%
Data4 = pd.read_excel('/content/drive/MyDrive/Data Mining/คำตอบนักประเมิน.xlsx',sheet_name=4).reset_index()
Data4
# Out:
#     index  ID ผู้ประเมิน                              post id  \
# 0       0              1    https://nayoo.co/khonkaen/posts/6
# 1       1              2    https://nayoo.co/khonkaen/posts/6
# 2       2              1   https://nayoo.co/khonkaen/posts/17
# 3       3              2   https://nayoo.co/khonkaen/posts/17
# 4       4              1   https://nayoo.co/khonkaen/posts/21
# 5       5              2   https://nayoo.co/khonkaen/posts/21
# 6       6              1   https://nayoo.co/khonkaen/posts/22
# 7       7              2   https://nayoo.co/khonkaen/posts/22
# 8       8              1   https://nayoo.co/khonkaen/posts/24
# 9       9              2   https://nayoo.co/khonkaen/posts/24
# 10     10              1   https://nayoo.co/khonkaen/posts/30
# 11     11              2   https://nayoo.co/khonkaen/posts/30
# 12     12              1   https://nayoo.co/khonkaen/posts/35
# 13     13              2   https://nayoo.co/khonkaen/posts/35
# ...

# %%
post_CB1 = Data4[Data4['ID ผู้ประเมิน']==1]
post_CB1
# Out:
#     index  ID ผู้ประเมิน                              post id  \
# 0       0              1    https://nayoo.co/khonkaen/posts/6
# 2       2              1   https://nayoo.co/khonkaen/posts/17
# 4       4              1   https://nayoo.co/khonkaen/posts/21
# 6       6              1   https://nayoo.co/khonkaen/posts/22
# 8       8              1   https://nayoo.co/khonkaen/posts/24
# 10     10              1   https://nayoo.co/khonkaen/posts/30
# 12     12              1   https://nayoo.co/khonkaen/posts/35
# 14     14              1  https://nayoo.co/khonkaen/posts/497
# 16     16              1  https://nayoo.co/khonkaen/posts/498
# 18     18              1  https://nayoo.co/khonkaen/posts/499
#
#             property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 0   อาคารพาณิชย์/สำนักงาน                        มั่นใจ   7000000.0
# 2   อาคารพาณิชย์/สำนักงาน                        มั่นใจ  12000000.0
# 4   อาคารพาณิชย์/สำนักงาน                        มั่นใจ  22500000.0
# ...

# %%
post_CB2 = Data4[Data4['ID ผู้ประเมิน']==2]
post_CB2
# Out:
#     index  ID ผู้ประเมิน                              post id  \
# 1       1              2    https://nayoo.co/khonkaen/posts/6
# 3       3              2   https://nayoo.co/khonkaen/posts/17
# 5       5              2   https://nayoo.co/khonkaen/posts/21
# 7       7              2   https://nayoo.co/khonkaen/posts/22
# 9       9              2   https://nayoo.co/khonkaen/posts/24
# 11     11              2   https://nayoo.co/khonkaen/posts/30
# 13     13              2   https://nayoo.co/khonkaen/posts/35
# 15     15              2  https://nayoo.co/khonkaen/posts/497
# 17     17              2  https://nayoo.co/khonkaen/posts/498
# 19     19              2  https://nayoo.co/khonkaen/posts/499
#
#             property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 1   อาคารพาณิชย์/สำนักงาน                        มั่นใจ   7000000.0
# 3   อาคารพาณิชย์/สำนักงาน                        มั่นใจ  12000000.0
# 5   อาคารพาณิชย์/สำนักงาน                        มั่นใจ  22500000.0
# ...

# %%
post_CB2['ประเมิน1'] = post_CB2['post id'].map(post_CB1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
post_CB2
# Out:
# <ipython-input-144-4e68ff42e0a2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   post_CB2['ประเมิน1'] = post_CB2['post id'].map(post_CB1.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#     index  ID ผู้ประเมิน                              post id  \
# 1       1              2    https://nayoo.co/khonkaen/posts/6
# 3       3              2   https://nayoo.co/khonkaen/posts/17
# 5       5              2   https://nayoo.co/khonkaen/posts/21
# 7       7              2   https://nayoo.co/khonkaen/posts/22
# 9       9              2   https://nayoo.co/khonkaen/posts/24
# 11     11              2   https://nayoo.co/khonkaen/posts/30
# 13     13              2   https://nayoo.co/khonkaen/posts/35
# ...

# %%
post_CB2_1 = post_CB2.rename(columns={"ประเมินราคาซื้อ-ขาย": "ประเมิน2"})
post_CB2_1
# Out:
#     index  ID ผู้ประเมิน                              post id  \
# 1       1              2    https://nayoo.co/khonkaen/posts/6
# 3       3              2   https://nayoo.co/khonkaen/posts/17
# 5       5              2   https://nayoo.co/khonkaen/posts/21
# 7       7              2   https://nayoo.co/khonkaen/posts/22
# 9       9              2   https://nayoo.co/khonkaen/posts/24
# 11     11              2   https://nayoo.co/khonkaen/posts/30
# 13     13              2   https://nayoo.co/khonkaen/posts/35
# 15     15              2  https://nayoo.co/khonkaen/posts/497
# 17     17              2  https://nayoo.co/khonkaen/posts/498
# 19     19              2  https://nayoo.co/khonkaen/posts/499
#
#             property_type ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  \
# 1   อาคารพาณิชย์/สำนักงาน                        มั่นใจ   7000000.0
# 3   อาคารพาณิชย์/สำนักงาน                        มั่นใจ  12000000.0
# 5   อาคารพาณิชย์/สำนักงาน                        มั่นใจ  22500000.0
# ...

# %%
total_CB = post_CB2_1[['post id','ราคาทรัพย์','ประเมิน1','ประเมิน2']]
total_CB
# Out:
#                                 post id  ราคาทรัพย์    ประเมิน1    ประเมิน2
# 1     https://nayoo.co/khonkaen/posts/6   7000000.0   6000000.0   8000000.0
# 3    https://nayoo.co/khonkaen/posts/17  12000000.0  12000000.0  12000000.0
# 5    https://nayoo.co/khonkaen/posts/21  22500000.0  13500000.0  20000000.0
# 7    https://nayoo.co/khonkaen/posts/22   3500000.0   4000000.0   4000000.0
# 9    https://nayoo.co/khonkaen/posts/24   3900000.0   2200000.0   3000000.0
# 11   https://nayoo.co/khonkaen/posts/30   4800000.0   3600000.0   4000000.0
# 13   https://nayoo.co/khonkaen/posts/35   2400000.0   2500000.0   2100000.0
# 15  https://nayoo.co/khonkaen/posts/497   5000000.0   3800000.0   5000000.0
# 17  https://nayoo.co/khonkaen/posts/498   7000000.0   7000000.0   8000000.0
# 19  https://nayoo.co/khonkaen/posts/499   9000000.0   8000000.0  10000000.0

# %%
x_true = total_CB['ราคาทรัพย์']
y_pred = total_CB['ประเมิน1']
z_pred = total_CB['ประเมิน2']

# %%
mean_absolute_percentage_error(x_true, y_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ{mean_absolute_percentage_error(x_true, y_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 1 เท่ากับ0.17643894993894996

# %%
mean_absolute_percentage_error(x_true, z_pred)
print(f'ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ{mean_absolute_percentage_error(x_true, z_pred)}')
# Out:
# ราคาตั้งขายเปรียบเทียบกับราคาประเมินทรัพย์ใช้ MAPE เป็นเกณฑ์ของนักประเมินคนที่ 2 เท่ากับ0.11732295482295482
